# %% [markdown]
# <a href="https://colab.research.google.com/github/wajeehaqaisar/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wajeehaqaisar/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# Regression
# Why: We are predicting a continuous number opportunity_score from 0 to 100 for each keyword

# %%
task_type = "Regression"
task_reason = "Predicting a continuous number: opportunity_score"
print(f"Lane: {task_type}")
print(f"Reason: {task_reason}")
# Out:
# Lane: Regression
# Reason: Predicting a continuous number: opportunity_score

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# Target: opportunity_score
# This is the label we want to predict for each keyword

# %%
target = "opportunity_score"
print(f"Target: {target}")
# Out:
# Target: opportunity_score

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# Features: search_volume, competition, kd_score
# These 3 inputs will be used to predict the opportunity_score

# %%
features = ["search_volume", "competition", "kd_score"]
print(f"Features: {features}")
# Out:
# Features: ['search_volume', 'competition', 'kd_score']

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
# Metric: R2 Score and MAE
# Why: R2 tells how well predictions match real opportunity_score. MAE tells average error in points

# %%
metric = "R2 Score and MAE"
print(f"Success Metric: {metric}")
# Out:
# Success Metric: R2 Score and MAE

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# Unit: 1 row = 1 keyword
# Each row represents one keyword with its search_volume, competition, and kd_score

# %%
unit = "1 row = 1 keyword"
print(f"Unit of Analysis: {unit}")
# Out:
# Unit of Analysis: 1 row = 1 keyword

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
